# %% [markdown]
# # Ejercicio análisis time series
# Para este ejercicio vas a trabajar con el histórico de valores en bolsa de una empresa que se dedica a vender muebles. Se pide
# 1. Importa los datos 'df_furniture.csv'
# 2. Trata la fecha como texto. Crea una columna para el año, mes y dia, y a partir de esas columnas crea la de fecha, en formato datetime de pandas
# 3. ¿De qué fecha a qué fecha va el histórico?
# 4. ¿Cómo es la serie temporal? ¿Tiene tendencia? ¿Aprecias alguna estacionalidad?
# 5. ¿Podrías demostrar de dos maneras estadísticas que la serie no es stationary?
# 6. Parece que hay una tendencia, pero no se aprecia bien con tanto pico en la serie. ¿Conoces algún método para representar mejor la tendencia?
# 7. Estaría bien visualizar todos los componentes de la serie temporal por separado
# 8. Demuestra mediante una gráfica de autocorrelación que la serie es estacional
# 9. ¿Qué dependencia tiene cada instante de sus ultimos 5 lags? Demuéstralo mediante una matriz de correlación. ¿Esto es bueno para los modelos?
# 10. Ya hemos visto que hay seasonality. ¿Cada cuántos instantes se cumple ese patrón?
# 11. Para un futuro modelado de los datos necesitaremos eliminar la tendencia. ¿Cómo hacemos esto?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("default")

# %% [markdown]
# ## 1. Importa los datos 'df_furniture.csv'

# %%
# Out:
#          Month  furniture_price_adjusted
# 0   1992-01-01               2073.432724
# 1   1992-02-01               2114.485812
# 2   1992-03-01               2260.570891
# 3   1992-04-01               2255.103236
# 4   1992-05-01               2331.414618
# ..         ...                       ...
# 326 2019-03-01               9718.107698
# 327 2019-04-01               9248.814254
# 328 2019-05-01              10001.305304
# 329 2019-06-01               9431.337229
# 330 2019-07-01               9887.800688
#
# [331 rows x 2 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     326 non-null    datetime64[ns]
#  1   furniture_price_adjusted  331 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.3 KB

# %%
# valores nulos
# Out:
#    Month  furniture_price_adjusted
# 15   NaT               2457.704334
# 21   NaT               2715.938414
# 39   NaT               2857.008678
# 40   NaT               3086.648631
# 60   NaT               3298.628987

# %%
# tamaño de la muestra
# Out:
# 331

# %%
# fecha mínima de la muestra
# Out:
# Timestamp('1992-01-01 00:00:00')

# %%
# fecha máxima de la muestra
# Out:
# Timestamp('2019-07-01 00:00:00')

# %%
# dado que la frecuencia es mensual, rellena los valores nulos

# puedes usar un date_range

# %%
# Out:
#          Month  furniture_price_adjusted
# 0   1992-01-01               2073.432724
# 1   1992-02-01               2114.485812
# 2   1992-03-01               2260.570891
# 3   1992-04-01               2255.103236
# 4   1992-05-01               2331.414618
# ..         ...                       ...
# 326 2019-03-01               9718.107698
# 327 2019-04-01               9248.814254
# 328 2019-05-01              10001.305304
# 329 2019-06-01               9431.337229
# 330 2019-07-01               9887.800688
#
# [331 rows x 2 columns]

# %%
# revisa si quedan nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     331 non-null    datetime64[ns]
#  1   furniture_price_adjusted  331 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.3 KB

# %% [markdown]
# ## 2. Trata la fecha como texto y parsea. Crea una columna para el año, mes y dia, y a partir de esas columnas crea la de fecha, en formato datetime de pandas

# %%
# Superconsejito: Haz un copy del df original para no pisarlo

# Esta parte del ejercicio es para repasar cómo parsear en caso de que recibas una fecha que no sea datetime, aunque no sea el caso

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331 entries, 0 to 330
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     331 non-null    datetime64[ns]
#  1   furniture_price_adjusted  331 non-null    float64
#  2   date_str                  331 non-null    object
#  3   year                      331 non-null    int32
#  4   month                     331 non-null    int32
#  5   day                       331 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(3), object(1)
# memory usage: 11.8+ KB

# %%
# Out:
#          Month  furniture_price_adjusted    date_str  year  month  day  \
# 0   1992-01-01               2073.432724  1992-01-01  1992      1    1
# 1   1992-02-01               2114.485812  1992-02-01  1992      2    1
# 2   1992-03-01               2260.570891  1992-03-01  1992      3    1
# 3   1992-04-01               2255.103236  1992-04-01  1992      4    1
# 4   1992-05-01               2331.414618  1992-05-01  1992      5    1
# ..         ...                       ...         ...   ...    ...  ...
# 326 2019-03-01               9718.107698  2019-03-01  2019      3    1
# 327 2019-04-01               9248.814254  2019-04-01  2019      4    1
# 328 2019-05-01              10001.305304  2019-05-01  2019      5    1
# 329 2019-06-01               9431.337229  2019-06-01  2019      6    1
# 330 2019-07-01               9887.800688  2019-07-01  2019      7    1
#
#       new_date
# 0   1992-01-01
# 1   1992-02-01
# 2   1992-03-01
# 3   1992-04-01
# 4   1992-05-01
# ..         ...
# 326 2019-03-01
# 327 2019-04-01
# 328 2019-05-01
# 329 2019-06-01
# 330 2019-07-01
#
# [331 rows x 7 columns]

# %% [markdown]
# ## 3. ¿De qué fecha a qué fecha va el histórico?

# %%
df
# Out:
#           Date  furniture_price_adjusted
# 0   1992-01-01               2073.432724
# 1   1992-02-01               2114.485812
# 2   1992-03-01               2260.570891
# 3   1992-04-01               2255.103236
# 4   1992-05-01               2331.414618
# ..         ...                       ...
# 326 2019-03-01               9718.107698
# 327 2019-04-01               9248.814254
# 328 2019-05-01              10001.305304
# 329 2019-06-01               9431.337229
# 330 2019-07-01               9887.800688
#
# [331 rows x 2 columns]

# %%
# min de la serie
# max de la serie
# Out:
# 1992-01-01 00:00:00
# 2019-07-01 00:00:00

# %% [markdown]
# La serie va desde enero de 1992 a julio de 2019

# %%
# cálcula el tamaño de la serie en años
# Out:
# 27.496235455167692

# %% [markdown]
# ## 4. ¿Cómo es la serie temporal? ¿Tiene tendencia? ¿Aprecias alguna estacionalidad?

# %%
df
# Out:
#             furniture_price_adjusted
# Date
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618
# ...                              ...
# 2019-03-01               9718.107698
# 2019-04-01               9248.814254
# 2019-05-01              10001.305304
# 2019-06-01               9431.337229
# 2019-07-01               9887.800688
#
# [331 rows x 1 columns]

# %%
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Se ve que tiene una tendencia al alza, a pesar de descenso en las acciones en el 2007.
#
# También apreciamos estacionalidad, al cumplirse cierto patrón a lo largo del tiempo

# %% [markdown]
# ## 5. ¿Podrías demostrar de dos maneras estadísticas que la serie no es stationary?

# %%
df
# Out:
#             furniture_price_adjusted
# Date
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618
# ...                              ...
# 2019-03-01               9718.107698
# 2019-04-01               9248.814254
# 2019-05-01              10001.305304
# 2019-06-01               9431.337229
# 2019-07-01               9887.800688
#
# [331 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# adfuller
# Out:
# 0.7035529748089981

# %%
# describe toda la serie
# Out:
#        furniture_price_adjusted
# count                331.000000
# mean                5975.765787
# std                 2092.867819
# min                 2073.432724
# 25%                 4280.088499
# 50%                 6075.405272
# 75%                 7381.403461
# max                10833.501852

# %%
# describe la primera mitad de la serie
# Out:
#        furniture_price_adjusted
# count                165.000000
# mean                4366.695881
# std                 1412.738867
# min                 2073.432724
# 25%                 3115.400080
# 50%                 4275.168742
# 75%                 5428.334524
# max                 8110.153770

# %%
# describe la segunda mitad de la serie
# Out:
#        furniture_price_adjusted
# count                166.000000
# mean                7575.142501
# std                 1270.370560
# min                 5349.481724
# 25%                 6613.056182
# 50%                 7345.578004
# 75%                 8439.580036
# max                10833.501852

# %% [markdown]
# ## 6. Parece que hay una tendencia, pero no se aprecia bien con tanto pico en la serie. ¿Conoces algún método para representar mejor la tendencia?

# %%
from statsmodels.nonparametric.smoothers_lowess import lowess

# %%
# Out:
# array([[0.00000000e+00, 2.20677961e+03],
#        [1.00000000e+00, 2.23030504e+03],
#        [2.00000000e+00, 2.25363575e+03],
#        [3.00000000e+00, 2.27680618e+03],
#        [4.00000000e+00, 2.29985791e+03],
#        [5.00000000e+00, 2.32283809e+03],
#        [6.00000000e+00, 2.34579369e+03],
#        [7.00000000e+00, 2.36876567e+03],
#        [8.00000000e+00, 2.39178496e+03],
#        [9.00000000e+00, 2.41487011e+03],
#        [1.00000000e+01, 2.43802959e+03],
#        [1.10000000e+01, 2.46124823e+03],
#        [1.20000000e+01, 2.48445239e+03],
#        [1.30000000e+01, 2.50744743e+03],
#        [1.40000000e+01, 2.52989409e+03],
#        [1.50000000e+01, 2.55115574e+03],
#        [1.60000000e+01, 2.57010550e+03],
#        [1.70000000e+01, 2.58724032e+03],
#        [1.80000000e+01, 2.60500821e+03],
#        [1.90000000e+01, 2.62421845e+03],
#        [2.00000000e+01, 2.64571834e+03],
#        [2.10000000e+01, 2.67009595e+03],
#        [2.20000000e+01, 2.69702042e+03],
#        [2.30000000e+01, 2.72551366e+03],
#        [2.40000000e+01, 2.75442653e+03],
#        [2.50000000e+01, 2.78246228e+03],
#        [2.60000000e+01, 2.80861216e+03],
#        [2.70000000e+01, 2.83225831e+03],
#        [2.80000000e+01, 2.85328780e+03],
#        [2.90000000e+01, 2.87258335e+03],
#        [3.00000000e+01, 2.89131455e+03],
#        [3.10000000e+01, 2.91052982e+03],
#        [1.61000000e+02, 6.75239707e+03],
#        [1.62000000e+02, 6.79285005e+03],
#        [1.63000000e+02, 6.83480659e+03],
#        [1.64000000e+02, 6.87958228e+03],
#        [1.65000000e+02, 6.92783431e+03],
#        [1.66000000e+02, 6.97826134e+03],
#        [1.67000000e+02, 7.02817033e+03],
#        [1.68000000e+02, 7.07488040e+03],
#        [1.69000000e+02, 7.11617940e+03],
#        [1.70000000e+02, 7.15112466e+03],
#        [1.71000000e+02, 7.17991702e+03],
#        [1.72000000e+02, 7.20370158e+03],
#        [1.73000000e+02, 7.22428985e+03],
#        [1.74000000e+02, 7.24271494e+03],
#        [1.75000000e+02, 7.25973537e+03],
#        [1.76000000e+02, 7.27662991e+03],
#        [1.77000000e+02, 7.29411187e+03],
#        [1.78000000e+02, 7.31113000e+03],
#        [1.79000000e+02, 7.32526022e+03],
#        [1.80000000e+02, 7.33348789e+03],
#        [1.81000000e+02, 7.33390709e+03],
#        [1.82000000e+02, 7.32682609e+03],
#        [1.83000000e+02, 7.31340132e+03],
#        [1.84000000e+02, 7.29538229e+03],
#        [1.85000000e+02, 7.27478412e+03],
#        [1.86000000e+02, 7.25246394e+03],
#        [1.87000000e+02, 7.22860498e+03],
#        [1.88000000e+02, 7.20402179e+03],
#        [1.89000000e+02, 7.17918334e+03],
#        [1.90000000e+02, 7.15321723e+03],
#        [1.91000000e+02, 7.12435261e+03],
#        [1.92000000e+02, 7.08994746e+03],
#        [1.93000000e+02, 7.04792370e+03],
#        [1.94000000e+02, 6.99727919e+03],
#        [1.95000000e+02, 6.93780468e+03],
#        [1.96000000e+02, 6.87096594e+03],
#        [1.97000000e+02, 6.79986703e+03],
#        [1.98000000e+02, 6.72735880e+03],
#        [1.99000000e+02, 6.65555537e+03],
#        [2.00000000e+02, 6.58646206e+03],
#        [2.01000000e+02, 6.52049090e+03],
#        [2.02000000e+02, 6.45708345e+03],
#        [2.03000000e+02, 6.39545956e+03],
#        [2.04000000e+02, 6.33530647e+03],
#        [2.05000000e+02, 6.27657749e+03],
#        [2.06000000e+02, 6.21907955e+03],
#        [2.07000000e+02, 6.16258291e+03],
#        [2.08000000e+02, 6.10782846e+03],
#        [2.09000000e+02, 6.05665737e+03],
#        [2.10000000e+02, 6.01102819e+03],
#        [2.11000000e+02, 5.97255616e+03],
#        [2.12000000e+02, 5.94305484e+03],
#        [2.13000000e+02, 5.92338674e+03],
#        [2.14000000e+02, 5.91352628e+03],
#        [2.15000000e+02, 5.91254744e+03],
#        [2.16000000e+02, 5.91887662e+03],
#        [2.17000000e+02, 5.93003952e+03],
#        [2.18000000e+02, 5.94350454e+03],
#        [2.19000000e+02, 5.95747407e+03],
#        [2.20000000e+02, 5.97158556e+03],
#        [2.21000000e+02, 5.98685946e+03],
#        [2.22000000e+02, 6.00429132e+03],
#        [2.23000000e+02, 6.02433413e+03],
#        [2.24000000e+02, 6.04779238e+03],
#        [2.25000000e+02, 6.07486148e+03],
#        [2.26000000e+02, 6.10484490e+03],
#        [2.27000000e+02, 6.13655935e+03],
#        [2.28000000e+02, 6.16894196e+03],
#        [2.29000000e+02, 6.20078325e+03],
#        [2.30000000e+02, 6.23153483e+03],
#        [2.31000000e+02, 6.26085112e+03],
#        [2.32000000e+02, 6.28911881e+03],
#        [2.33000000e+02, 6.31761517e+03],
#        [2.34000000e+02, 6.34702077e+03],
#        [2.35000000e+02, 6.37733055e+03],
#        [2.36000000e+02, 6.40934451e+03],
#        [2.37000000e+02, 6.44343384e+03],
#        [2.38000000e+02, 6.47891961e+03],
#        [2.39000000e+02, 6.51430182e+03],
#        [2.40000000e+02, 6.54825116e+03],
#        [2.41000000e+02, 6.57989074e+03],
#        [2.42000000e+02, 6.60918969e+03],
#        [2.43000000e+02, 6.63618279e+03],
#        [2.44000000e+02, 6.66174514e+03],
#        [2.45000000e+02, 6.68761525e+03],
#        [2.46000000e+02, 6.71486406e+03],
#        [2.47000000e+02, 6.74393415e+03],
#        [2.48000000e+02, 6.77579598e+03],
#        [2.49000000e+02, 6.81106649e+03],
#        [2.50000000e+02, 6.84945116e+03],
#        [2.51000000e+02, 6.88975367e+03],
#        [2.52000000e+02, 6.93022476e+03],
#        [2.53000000e+02, 6.96932016e+03],
#        [2.54000000e+02, 7.00655014e+03],
#        [2.55000000e+02, 7.04158334e+03],
#        [2.56000000e+02, 7.07537533e+03],
#        [2.57000000e+02, 7.10983668e+03],
#        [2.58000000e+02, 7.14619700e+03],
#        [2.59000000e+02, 7.18513372e+03],
#        [2.60000000e+02, 7.22767962e+03],
#        [2.61000000e+02, 7.27376589e+03],
#        [2.62000000e+02, 7.32252171e+03],
#        [2.63000000e+02, 7.37252664e+03],
#        [2.64000000e+02, 7.42178412e+03],
#        [2.65000000e+02, 7.46855906e+03],
#        [2.66000000e+02, 7.51210375e+03],
#        [2.67000000e+02, 7.55209922e+03],
#        [2.68000000e+02, 7.58961011e+03],
#        [2.69000000e+02, 7.62644534e+03],
#        [2.70000000e+02, 7.66389478e+03],
#        [2.71000000e+02, 7.70282363e+03],
#        [2.72000000e+02, 7.74449082e+03],
#        [2.73000000e+02, 7.78951164e+03],
#        [2.74000000e+02, 7.83772859e+03],
#        [2.75000000e+02, 7.88767811e+03],
#        [2.76000000e+02, 7.93725904e+03],
#        [2.77000000e+02, 7.98432758e+03],
#        [2.78000000e+02, 8.02730138e+03],
#        [2.79000000e+02, 8.06563053e+03],
#        [2.80000000e+02, 8.10016445e+03],
#        [2.81000000e+02, 8.13308627e+03],
#        [2.82000000e+02, 8.16629391e+03],
#        [2.83000000e+02, 8.20083768e+03],
#        [2.84000000e+02, 8.23788253e+03],
#        [2.85000000e+02, 8.27781791e+03],
#        [2.86000000e+02, 8.32056094e+03],
#        [2.87000000e+02, 8.36491273e+03],
#        [2.88000000e+02, 8.40917584e+03],
#        [2.89000000e+02, 8.45151350e+03],
#        [2.90000000e+02, 8.49068099e+03],
#        [2.91000000e+02, 8.52614297e+03],
#        [2.92000000e+02, 8.55827918e+03],
#        [2.93000000e+02, 8.58878070e+03],
#        [2.94000000e+02, 8.61906636e+03],
#        [2.95000000e+02, 8.65037577e+03],
#        [2.96000000e+02, 8.68435238e+03],
#        [2.97000000e+02, 8.72184366e+03],
#        [2.98000000e+02, 8.76279779e+03],
#        [2.99000000e+02, 8.80623887e+03],
#        [3.00000000e+02, 8.85080236e+03],
#        [3.01000000e+02, 8.89466009e+03],
#        [3.02000000e+02, 8.93681354e+03],
#        [3.03000000e+02, 8.97697855e+03],
#        [3.04000000e+02, 9.01547113e+03],
#        [3.05000000e+02, 9.05314635e+03],
#        [3.06000000e+02, 9.09000956e+03],
#        [3.07000000e+02, 9.12601092e+03],
#        [3.08000000e+02, 9.16269019e+03],
#        [3.09000000e+02, 9.20166262e+03],
#        [3.10000000e+02, 9.24382942e+03],
#        [3.11000000e+02, 9.28901388e+03],
#        [3.12000000e+02, 9.33532069e+03],
#        [3.13000000e+02, 9.38011905e+03],
#        [3.14000000e+02, 9.42167670e+03],
#        [3.15000000e+02, 9.45050917e+03],
#        [3.16000000e+02, 9.47498828e+03],
#        [3.17000000e+02, 9.49938364e+03],
#        [3.18000000e+02, 9.52446547e+03],
#        [3.19000000e+02, 9.55008232e+03],
#        [3.20000000e+02, 9.57599772e+03],
#        [3.21000000e+02, 9.60199257e+03],
#        [3.22000000e+02, 9.62792878e+03],
#        [3.23000000e+02, 9.65370525e+03],
#        [3.24000000e+02, 9.67920174e+03],
#        [3.25000000e+02, 9.70430250e+03],
#        [3.26000000e+02, 9.72891868e+03],
#        [3.27000000e+02, 9.75298278e+03],
#        [3.28000000e+02, 9.77645744e+03],
#        [3.29000000e+02, 9.79936028e+03],
#        [3.30000000e+02, 9.82170660e+03]])

# %%
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 7. Estaría bien visualizar todos los componentes de la serie temporal por separado

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# model = "additive"

# %%
# model = "multiplicative"

# %% [markdown]
# ## 8. Demuestra mediante una gráfica de autocorrelación que la serie es estacional

# %%
from pandas.plotting import autocorrelation_plot

# %% [markdown]
# ## 9. ¿Qué dependencia tiene cada instante de sus ultimos 5 lags? Demuestralo mediante una matriz de correlación.

# %%
# Superconsejito: Haz un copy del df original para no pisarlo

# %%
# df_2.head(20)
# Out:
#             furniture_price_adjusted         lag1         lag2         lag3  \
# Date
# 1992-01-01               2073.432724          NaN          NaN          NaN
# 1992-02-01               2114.485812  2073.432724          NaN          NaN
# 1992-03-01               2260.570891  2114.485812  2073.432724          NaN
# 1992-04-01               2255.103236  2260.570891  2114.485812  2073.432724
# 1992-05-01               2331.414618  2255.103236  2260.570891  2114.485812
# 1992-06-01               2384.638567  2331.414618  2255.103236  2260.570891
# 1992-07-01               2417.165376  2384.638567  2331.414618  2255.103236
# 1992-08-01               2445.498729  2417.165376  2384.638567  2331.414618
# 1992-09-01               2387.351705  2445.498729  2417.165376  2384.638567
# 1992-10-01               2489.350838  2387.351705  2445.498729  2417.165376
# 1992-11-01               2598.186297  2489.350838  2387.351705  2445.498729
# 1992-12-01               2928.725684  2598.186297  2489.350838  2387.351705
# 1993-01-01               2284.619439  2928.725684  2598.186297  2489.350838
# 1993-02-01               2183.137948  2284.619439  2928.725684  2598.186297
# 1993-03-01               2449.195623  2183.137948  2284.619439  2928.725684
# 1993-04-01               2457.704334  2449.195623  2183.137948  2284.619439
# 1993-05-01               2552.874950  2457.704334  2449.195623  2183.137948
# 1993-06-01               2575.018055  2552.874950  2457.704334  2449.195623
# 1993-07-01               2639.280765  2575.018055  2552.874950  2457.704334
# 1993-08-01               2675.420536  2639.280765  2575.018055  2552.874950
#
#                    lag4         lag5
# Date
# 1992-01-01          NaN          NaN
# 1992-02-01          NaN          NaN
# 1992-03-01          NaN          NaN
# 1992-04-01          NaN          NaN
# 1992-05-01  2073.432724          NaN
# 1992-06-01  2114.485812  2073.432724
# 1992-07-01  2260.570891  2114.485812
# 1992-08-01  2255.103236  2260.570891
# 1992-09-01  2331.414618  2255.103236
# 1992-10-01  2384.638567  2331.414618
# 1992-11-01  2417.165376  2384.638567
# 1992-12-01  2445.498729  2417.165376
# 1993-01-01  2387.351705  2445.498729
# 1993-02-01  2489.350838  2387.351705
# 1993-03-01  2598.186297  2489.350838
# 1993-04-01  2928.725684  2598.186297
# 1993-05-01  2284.619439  2928.725684
# 1993-06-01  2183.137948  2284.619439
# 1993-07-01  2449.195623  2183.137948
# 1993-08-01  2457.704334  2449.195623

# %%
# Matriz de correlación
# Out:
#                           furniture_price_adjusted      lag1      lag2  \
# furniture_price_adjusted                  1.000000  0.951005  0.928338
# lag1                                      0.951005  1.000000  0.950599
# lag2                                      0.928338  0.950599  1.000000
# lag3                                      0.945035  0.927538  0.950224
# lag4                                      0.940613  0.944637  0.926949
# lag5                                      0.935901  0.939980  0.944155
#
#                               lag3      lag4      lag5
# furniture_price_adjusted  0.945035  0.940613  0.935901
# lag1                      0.927538  0.944637  0.939980
# lag2                      0.950224  0.926949  0.944155
# lag3                      1.000000  0.949927  0.926156
# lag4                      0.949927  1.000000  0.949554
# lag5                      0.926156  0.949554  1.000000

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 10. Ya hemos visto que hay seasonality. ¿Cada cuántos instantes se cumple ese patrón?

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
# lags=50

# %% [markdown]
# ## 11. Para un futuro modelado de los datos necesitaremos eliminar la tendencia. ¿Cómo hacemos esto?

# %%
df
# Out:
#             furniture_price_adjusted
# Date
# 1992-01-01               2073.432724
# 1992-02-01               2114.485812
# 1992-03-01               2260.570891
# 1992-04-01               2255.103236
# 1992-05-01               2331.414618
# ...                              ...
# 2019-03-01               9718.107698
# 2019-04-01               9248.814254
# 2019-05-01              10001.305304
# 2019-06-01               9431.337229
# 2019-07-01               9887.800688
#
# [331 rows x 1 columns]

# %%
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# diff = df['furniture_price_adjusted'].diff(1).dropna()
# diff.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
