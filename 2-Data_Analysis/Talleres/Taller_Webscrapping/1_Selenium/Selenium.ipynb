# %% [markdown]
# # Web Scraping: Selenium

# %% [markdown]
# A menudo, los datos están disponibles públicamente para nosotros, pero no en una forma que sea fácilmente utilizable. Ahí es donde entra en juego el web scraping, podemos usar web scraping para obtener nuestros datos deseados en un formato conveniente que luego se puede usar. a continuación, mostraré cómo se puede extraer información de interés de un sitio web usando el paquete Selenium en Python. Selenium nos permite manejar una ventana del navegador e interactuar con el sitio web mediante programación.
#
# Selenium también tiene varios métodos que facilitan la extracción de datos.
# En este Jupyter Notebook vamos a usar Python 3 en Windows.
#
# En primer lugar, tendremos que descargar un controlador.
#
# Usaremos ChromeDriver para Google Chrome. Para obtener una lista completa de controladores y plataformas compatibles, consulte [Selenium](https://www.selenium.dev/downloads/). Si desea utilizar Google Chrome, diríjase a [chrome](https://chromedriver.chromium.org/) y descargue el controlador que corresponde a su versión actual de Google Chrome.
#
# Como saber cual es la version de chrome que utilizo simple utilizamos pegamos el siguiente enlace en la barra de chrome chrome://settings/help
#
# Antes de comenzar se preguntaran si ya se BeautifulSoup cual es la diferencia con Selenium.
#
# A diferencia BeautifulSoup, Selenium no trabaja con el texto fuente en HTML de la web en cuestión, sino que carga la página en un navegador sin interfaz de usuario. El navegador interpreta entonces el código fuente de la página y crea, a partir de él, un Document Object Model (modelo de objetos de documento o DOM). Esta interfaz estandarizada permite poner a prueba las interacciones de los usuarios. De esta forma se consigue, por ejemplo, simular clics y rellenar formularios automáticamente. Los cambios en la web que resultan de dichas acciones se reflejan en el DOM. La estructura del proceso de web scraping con Selenium es la siguiente:
#
# URL → Solicitud HTTP → HTML → Selenium → DOM

# %% [markdown]
# ---
# ---
# ---
# ## La forma que en verdad vamos a trabajar o por lo menos la que mejor nos funciono mejor...

# %%
#!pip install selenium

# %%
#!pip install webdriver-manager

# %%
from bs4 import BeautifulSoup as bs
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

import time
import pandas as pd

# %%
driver = webdriver.Chrome()

url = "https://boardgamegeek.com/"

driver.get(url)

# %%
# Cookies = driver.find_element_by_css_selector("a.btn.btn-sm")
# Detalle a comentar de las diferentes formas de hacerlo
# https://stackoverflow.com/questions/7475449/webdriver-classname-with-space-using-java
# https://selenium-python.readthedocs.io/locating-elements.html
# https://saucelabs.com/resources/articles/selenium-tips-css-selectors

Cookies = driver.find_element(By.XPATH, "/html/body/div[3]/div/div[1]/div/div[2]/button[1]")

# %%
Cookies.click()

# %%
pagina = driver.find_element(By.XPATH, '/html/body/gg-app/div/main/div/div/gg-home/div/gg-home-game-explorer-row-hotness/gg-home-game-explorer-row/section/header/h2/a')

# %%
pagina.click()

# %%
soup = bs(driver.page_source,"lxml")

# %%
soup
# Out:
# <html lang="en-US"><head>
# <style type="text/css">:root, :host {
#   --fa-font-solid: normal 900 1em/1 "Font Awesome 6 Solid";
#   --fa-font-regular: normal 400 1em/1 "Font Awesome 6 Regular";
#   --fa-font-light: normal 300 1em/1 "Font Awesome 6 Light";
#   --fa-font-thin: normal 100 1em/1 "Font Awesome 6 Thin";
#   --fa-font-duotone: normal 900 1em/1 "Font Awesome 6 Duotone";
#   --fa-font-sharp-solid: normal 900 1em/1 "Font Awesome 6 Sharp";
#   --fa-font-sharp-regular: normal 400 1em/1 "Font Awesome 6 Sharp";
#   --fa-font-sharp-light: normal 300 1em/1 "Font Awesome 6 Sharp";
#   --fa-font-brands: normal 400 1em/1 "Font Awesome 6 Brands";
# }
#
# svg:not(:root).svg-inline--fa, svg:not(:host).svg-inline--fa {
#   overflow: visible;
#   box-sizing: content-box;
# }
#
# .svg-inline--fa {
#   display: var(--fa-display, inline-block);
#   height: 1em;
#   overflow: visible;
#   vertical-align: -0.125em;
# }
# .svg-inline--fa.fa-2xs {
#   vertical-align: 0.1em;
# }
# .svg-inline--fa.fa-xs {
#   vertical-align: 0em;
# }
# .svg-inline--fa.fa-sm {
#   vertical-align: -0.0714285705em;
# }
# .svg-inline--fa.fa-lg {
#   vertical-align: -0.2em;
# }
# .svg-inline--fa.fa-xl {
#   vertical-align: -0.25em;
# }
# .svg-inline--fa.fa-2xl {
#   vertical-align: -0.3125em;
# }
# .svg-inline--fa.fa-pull-left {
#   margin-right: var(--fa-pull-margin, 0.3em);
#   width: auto;
# }
# .svg-inline--fa.fa-pull-right {
#   margin-left: var(--fa-pull-margin, 0.3em);
#   width: auto;
# }
# .svg-inline--fa.fa-li {
#   width: var(--fa-li-width, 2em);
#   top: 0.25em;
# }
# .svg-inline--fa.fa-fw {
#   width: var(--fa-fw-width, 1.25em);
# }
#
# .fa-layers svg.svg-inline--fa {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
# }
#
# .fa-layers-counter, .fa-layers-text {
#   display: inline-block;
#   position: absolute;
#   text-align: center;
# }
#
# .fa-layers {
#   display: inline-block;
#   height: 1em;
#   position: relative;
#   text-align: center;
#   vertical-align: -0.125em;
#   width: 1em;
# }
# .fa-layers svg.svg-inline--fa {
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-text {
#   left: 50%;
#   top: 50%;
#   -webkit-transform: translate(-50%, -50%);
#           transform: translate(-50%, -50%);
#   -webkit-transform-origin: center center;
#           transform-origin: center center;
# }
#
# .fa-layers-counter {
#   background-color: var(--fa-counter-background-color, #ff253a);
#   border-radius: var(--fa-counter-border-radius, 1em);
#   box-sizing: border-box;
#   color: var(--fa-inverse, #fff);
#   line-height: var(--fa-counter-line-height, 1);
#   max-width: var(--fa-counter-max-width, 5em);
#   min-width: var(--fa-counter-min-width, 1.5em);
#   overflow: hidden;
#   padding: var(--fa-counter-padding, 0.25em 0.5em);
#   right: var(--fa-right, 0);
#   text-overflow: ellipsis;
#   top: var(--fa-top, 0);
#   -webkit-transform: scale(var(--fa-counter-scale, 0.25));
#           transform: scale(var(--fa-counter-scale, 0.25));
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-bottom-right {
#   bottom: var(--fa-bottom, 0);
#   right: var(--fa-right, 0);
#   top: auto;
#   -webkit-transform: scale(var(--fa-layers-scale, 0.25));
#           transform: scale(var(--fa-layers-scale, 0.25));
#   -webkit-transform-origin: bottom right;
#           transform-origin: bottom right;
# }
#
# .fa-layers-bottom-left {
#   bottom: var(--fa-bottom, 0);
#   left: var(--fa-left, 0);
#   right: auto;
#   top: auto;
#   -webkit-transform: scale(var(--fa-layers-scale, 0.25));
#           transform: scale(var(--fa-layers-scale, 0.25));
#   -webkit-transform-origin: bottom left;
#           transform-origin: bottom left;
# }
#
# .fa-layers-top-right {
#   top: var(--fa-top, 0);
#   right: var(--fa-right, 0);
#   -webkit-transform: scale(var(--fa-layers-scale, 0.25));
#           transform: scale(var(--fa-layers-scale, 0.25));
#   -webkit-transform-origin: top right;
#           transform-origin: top right;
# }
#
# .fa-layers-top-left {
#   left: var(--fa-left, 0);
#   right: auto;
#   top: var(--fa-top, 0);
#   -webkit-transform: scale(var(--fa-layers-scale, 0.25));
#           transform: scale(var(--fa-layers-scale, 0.25));
#   -webkit-transform-origin: top left;
#           transform-origin: top left;
# }
#
# .fa-1x {
#   font-size: 1em;
# }
#
# .fa-2x {
#   font-size: 2em;
# }
#
# .fa-3x {
#   font-size: 3em;
# }
#
# .fa-4x {
#   font-size: 4em;
# }
#
# .fa-5x {
#   font-size: 5em;
# }
#
# .fa-6x {
#   font-size: 6em;
# }
#
# .fa-7x {
#   font-size: 7em;
# }
#
# .fa-8x {
#   font-size: 8em;
# }
#
# .fa-9x {
#   font-size: 9em;
# }
#
# .fa-10x {
#   font-size: 10em;
# }
#
# .fa-2xs {
#   font-size: 0.625em;
#   line-height: 0.1em;
#   vertical-align: 0.225em;
# }
#
# .fa-xs {
#   font-size: 0.75em;
#   line-height: 0.0833333337em;
#   vertical-align: 0.125em;
# }
#
# .fa-sm {
#   font-size: 0.875em;
#   line-height: 0.0714285718em;
#   vertical-align: 0.0535714295em;
# }
#
# .fa-lg {
#   font-size: 1.25em;
#   line-height: 0.05em;
#   vertical-align: -0.075em;
# }
#
# .fa-xl {
#   font-size: 1.5em;
#   line-height: 0.0416666682em;
#   vertical-align: -0.125em;
# }
#
# .fa-2xl {
#   font-size: 2em;
#   line-height: 0.03125em;
#   vertical-align: -0.1875em;
# }
#
# .fa-fw {
#   text-align: center;
#   width: 1.25em;
# }
#
# .fa-ul {
#   list-style-type: none;
#   margin-left: var(--fa-li-margin, 2.5em);
#   padding-left: 0;
# }
# .fa-ul > li {
#   position: relative;
# }
#
# .fa-li {
#   left: calc(var(--fa-li-width, 2em) * -1);
#   position: absolute;
#   text-align: center;
#   width: var(--fa-li-width, 2em);
#   line-height: inherit;
# }
#
# .fa-border {
#   border-color: var(--fa-border-color, #eee);
#   border-radius: var(--fa-border-radius, 0.1em);
#   border-style: var(--fa-border-style, solid);
#   border-width: var(--fa-border-width, 0.08em);
#   padding: var(--fa-border-padding, 0.2em 0.25em 0.15em);
# }
#
# .fa-pull-left {
#   float: left;
#   margin-right: var(--fa-pull-margin, 0.3em);
# }
#
# .fa-pull-right {
#   float: right;
#   margin-left: var(--fa-pull-margin, 0.3em);
# }
#
# .fa-beat {
#   -webkit-animation-name: fa-beat;
#           animation-name: fa-beat;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, ease-in-out);
#           animation-timing-function: var(--fa-animation-timing, ease-in-out);
# }
#
# .fa-bounce {
#   -webkit-animation-name: fa-bounce;
#           animation-name: fa-bounce;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.28, 0.84, 0.42, 1));
#           animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.28, 0.84, 0.42, 1));
# }
#
# .fa-fade {
#   -webkit-animation-name: fa-fade;
#           animation-name: fa-fade;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.4, 0, 0.6, 1));
#           animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.4, 0, 0.6, 1));
# }
#
# .fa-beat-fade {
#   -webkit-animation-name: fa-beat-fade;
#           animation-name: fa-beat-fade;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.4, 0, 0.6, 1));
#           animation-timing-function: var(--fa-animation-timing, cubic-bezier(0.4, 0, 0.6, 1));
# }
#
# .fa-flip {
#   -webkit-animation-name: fa-flip;
#           animation-name: fa-flip;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, ease-in-out);
#           animation-timing-function: var(--fa-animation-timing, ease-in-out);
# }
#
# .fa-shake {
#   -webkit-animation-name: fa-shake;
#           animation-name: fa-shake;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, linear);
#           animation-timing-function: var(--fa-animation-timing, linear);
# }
#
# .fa-spin {
#   -webkit-animation-name: fa-spin;
#           animation-name: fa-spin;
#   -webkit-animation-delay: var(--fa-animation-delay, 0s);
#           animation-delay: var(--fa-animation-delay, 0s);
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 2s);
#           animation-duration: var(--fa-animation-duration, 2s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, linear);
#           animation-timing-function: var(--fa-animation-timing, linear);
# }
#
# .fa-spin-reverse {
#   --fa-animation-direction: reverse;
# }
#
# .fa-pulse,
# .fa-spin-pulse {
#   -webkit-animation-name: fa-spin;
#           animation-name: fa-spin;
#   -webkit-animation-direction: var(--fa-animation-direction, normal);
#           animation-direction: var(--fa-animation-direction, normal);
#   -webkit-animation-duration: var(--fa-animation-duration, 1s);
#           animation-duration: var(--fa-animation-duration, 1s);
#   -webkit-animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#           animation-iteration-count: var(--fa-animation-iteration-count, infinite);
#   -webkit-animation-timing-function: var(--fa-animation-timing, steps(8));
#           animation-timing-function: var(--fa-animation-timing, steps(8));
# }
#
# @media (prefers-reduced-motion: reduce) {
#   .fa-beat,
# .fa-bounce,
# .fa-fade,
# .fa-beat-fade,
# .fa-flip,
# .fa-pulse,
# .fa-shake,
# .fa-spin,
# .fa-spin-pulse {
#     -webkit-animation-delay: -1ms;
#             animation-delay: -1ms;
#     -webkit-animation-duration: 1ms;
#             animation-duration: 1ms;
#     -webkit-animation-iteration-count: 1;
#             animation-iteration-count: 1;
#     -webkit-transition-delay: 0s;
#             transition-delay: 0s;
#     -webkit-transition-duration: 0s;
#             transition-duration: 0s;
#   }
# }
# @-webkit-keyframes fa-beat {
#   0%, 90% {
#     -webkit-transform: scale(1);
#             transform: scale(1);
#   }
#   45% {
#     -webkit-transform: scale(var(--fa-beat-scale, 1.25));
#             transform: scale(var(--fa-beat-scale, 1.25));
#   }
# }
# @keyframes fa-beat {
#   0%, 90% {
#     -webkit-transform: scale(1);
#             transform: scale(1);
#   }
#   45% {
#     -webkit-transform: scale(var(--fa-beat-scale, 1.25));
#             transform: scale(var(--fa-beat-scale, 1.25));
#   }
# }
# @-webkit-keyframes fa-bounce {
#   0% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
#   10% {
#     -webkit-transform: scale(var(--fa-bounce-start-scale-x, 1.1), var(--fa-bounce-start-scale-y, 0.9)) translateY(0);
#             transform: scale(var(--fa-bounce-start-scale-x, 1.1), var(--fa-bounce-start-scale-y, 0.9)) translateY(0);
#   }
#   30% {
#     -webkit-transform: scale(var(--fa-bounce-jump-scale-x, 0.9), var(--fa-bounce-jump-scale-y, 1.1)) translateY(var(--fa-bounce-height, -0.5em));
#             transform: scale(var(--fa-bounce-jump-scale-x, 0.9), var(--fa-bounce-jump-scale-y, 1.1)) translateY(var(--fa-bounce-height, -0.5em));
#   }
#   50% {
#     -webkit-transform: scale(var(--fa-bounce-land-scale-x, 1.05), var(--fa-bounce-land-scale-y, 0.95)) translateY(0);
#             transform: scale(var(--fa-bounce-land-scale-x, 1.05), var(--fa-bounce-land-scale-y, 0.95)) translateY(0);
#   }
#   57% {
#     -webkit-transform: scale(1, 1) translateY(var(--fa-bounce-rebound, -0.125em));
#             transform: scale(1, 1) translateY(var(--fa-bounce-rebound, -0.125em));
#   }
#   64% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
#   100% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
# }
# @keyframes fa-bounce {
#   0% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
#   10% {
#     -webkit-transform: scale(var(--fa-bounce-start-scale-x, 1.1), var(--fa-bounce-start-scale-y, 0.9)) translateY(0);
#             transform: scale(var(--fa-bounce-start-scale-x, 1.1), var(--fa-bounce-start-scale-y, 0.9)) translateY(0);
#   }
#   30% {
#     -webkit-transform: scale(var(--fa-bounce-jump-scale-x, 0.9), var(--fa-bounce-jump-scale-y, 1.1)) translateY(var(--fa-bounce-height, -0.5em));
#             transform: scale(var(--fa-bounce-jump-scale-x, 0.9), var(--fa-bounce-jump-scale-y, 1.1)) translateY(var(--fa-bounce-height, -0.5em));
#   }
#   50% {
#     -webkit-transform: scale(var(--fa-bounce-land-scale-x, 1.05), var(--fa-bounce-land-scale-y, 0.95)) translateY(0);
#             transform: scale(var(--fa-bounce-land-scale-x, 1.05), var(--fa-bounce-land-scale-y, 0.95)) translateY(0);
#   }
#   57% {
#     -webkit-transform: scale(1, 1) translateY(var(--fa-bounce-rebound, -0.125em));
#             transform: scale(1, 1) translateY(var(--fa-bounce-rebound, -0.125em));
#   }
#   64% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
#   100% {
#     -webkit-transform: scale(1, 1) translateY(0);
#             transform: scale(1, 1) translateY(0);
#   }
# }
# @-webkit-keyframes fa-fade {
#   50% {
#     opacity: var(--fa-fade-opacity, 0.4);
#   }
# }
# @keyframes fa-fade {
#   50% {
#     opacity: var(--fa-fade-opacity, 0.4);
#   }
# }
# @-webkit-keyframes fa-beat-fade {
#   0%, 100% {
#     opacity: var(--fa-beat-fade-opacity, 0.4);
#     -webkit-transform: scale(1);
#             transform: scale(1);
#   }
#   50% {
#     opacity: 1;
#     -webkit-transform: scale(var(--fa-beat-fade-scale, 1.125));
#             transform: scale(var(--fa-beat-fade-scale, 1.125));
#   }
# }
# @keyframes fa-beat-fade {
#   0%, 100% {
#     opacity: var(--fa-beat-fade-opacity, 0.4);
#     -webkit-transform: scale(1);
#             transform: scale(1);
#   }
#   50% {
#     opacity: 1;
#     -webkit-transform: scale(var(--fa-beat-fade-scale, 1.125));
#             transform: scale(var(--fa-beat-fade-scale, 1.125));
#   }
# }
# @-webkit-keyframes fa-flip {
#   50% {
#     -webkit-transform: rotate3d(var(--fa-flip-x, 0), var(--fa-flip-y, 1), var(--fa-flip-z, 0), var(--fa-flip-angle, -180deg));
#             transform: rotate3d(var(--fa-flip-x, 0), var(--fa-flip-y, 1), var(--fa-flip-z, 0), var(--fa-flip-angle, -180deg));
#   }
# }
# @keyframes fa-flip {
#   50% {
#     -webkit-transform: rotate3d(var(--fa-flip-x, 0), var(--fa-flip-y, 1), var(--fa-flip-z, 0), var(--fa-flip-angle, -180deg));
#             transform: rotate3d(var(--fa-flip-x, 0), var(--fa-flip-y, 1), var(--fa-flip-z, 0), var(--fa-flip-angle, -180deg));
#   }
# }
# @-webkit-keyframes fa-shake {
#   0% {
#     -webkit-transform: rotate(-15deg);
#             transform: rotate(-15deg);
#   }
#   4% {
#     -webkit-transform: rotate(15deg);
#             transform: rotate(15deg);
#   }
#   8%, 24% {
#     -webkit-transform: rotate(-18deg);
#             transform: rotate(-18deg);
#   }
#   12%, 28% {
#     -webkit-transform: rotate(18deg);
#             transform: rotate(18deg);
#   }
#   16% {
#     -webkit-transform: rotate(-22deg);
#             transform: rotate(-22deg);
#   }
#   20% {
#     -webkit-transform: rotate(22deg);
#             transform: rotate(22deg);
#   }
#   32% {
#     -webkit-transform: rotate(-12deg);
#             transform: rotate(-12deg);
#   }
#   36% {
#     -webkit-transform: rotate(12deg);
#             transform: rotate(12deg);
#   }
#   40%, 100% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
# }
# @keyframes fa-shake {
#   0% {
#     -webkit-transform: rotate(-15deg);
#             transform: rotate(-15deg);
#   }
#   4% {
#     -webkit-transform: rotate(15deg);
#             transform: rotate(15deg);
#   }
#   8%, 24% {
#     -webkit-transform: rotate(-18deg);
#             transform: rotate(-18deg);
#   }
#   12%, 28% {
#     -webkit-transform: rotate(18deg);
#             transform: rotate(18deg);
#   }
#   16% {
#     -webkit-transform: rotate(-22deg);
#             transform: rotate(-22deg);
#   }
#   20% {
#     -webkit-transform: rotate(22deg);
#             transform: rotate(22deg);
#   }
#   32% {
#     -webkit-transform: rotate(-12deg);
#             transform: rotate(-12deg);
#   }
#   36% {
#     -webkit-transform: rotate(12deg);
#             transform: rotate(12deg);
#   }
#   40%, 100% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
# }
# @-webkit-keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
# @keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg);
#   }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg);
#   }
# }
# .fa-rotate-90 {
#   -webkit-transform: rotate(90deg);
#           transform: rotate(90deg);
# }
#
# .fa-rotate-180 {
#   -webkit-transform: rotate(180deg);
#           transform: rotate(180deg);
# }
#
# .fa-rotate-270 {
#   -webkit-transform: rotate(270deg);
#           transform: rotate(270deg);
# }
#
# .fa-flip-horizontal {
#   -webkit-transform: scale(-1, 1);
#           transform: scale(-1, 1);
# }
#
# .fa-flip-vertical {
#   -webkit-transform: scale(1, -1);
#           transform: scale(1, -1);
# }
#
# .fa-flip-both,
# .fa-flip-horizontal.fa-flip-vertical {
#   -webkit-transform: scale(-1, -1);
#           transform: scale(-1, -1);
# }
#
# .fa-rotate-by {
#   -webkit-transform: rotate(var(--fa-rotate-angle, none));
#           transform: rotate(var(--fa-rotate-angle, none));
# }
#
# .fa-stack {
#   display: inline-block;
#   vertical-align: middle;
#   height: 2em;
#   position: relative;
#   width: 2.5em;
# }
#
# .fa-stack-1x,
# .fa-stack-2x {
#   bottom: 0;
#   left: 0;
#   margin: auto;
#   position: absolute;
#   right: 0;
#   top: 0;
#   z-index: var(--fa-stack-z-index, auto);
# }
#
# .svg-inline--fa.fa-stack-1x {
#   height: 1em;
#   width: 1.25em;
# }
# .svg-inline--fa.fa-stack-2x {
#   height: 2em;
#   width: 2.5em;
# }
#
# .fa-inverse {
#   color: var(--fa-inverse, #fff);
# }
#
# .sr-only,
# .fa-sr-only {
#   position: absolute;
#   width: 1px;
#   height: 1px;
#   padding: 0;
#   margin: -1px;
#   overflow: hidden;
#   clip: rect(0, 0, 0, 0);
#   white-space: nowrap;
#   border-width: 0;
# }
#
# .sr-only-focusable:not(:focus),
# .fa-sr-only-focusable:not(:focus) {
#   position: absolute;
#   width: 1px;
#   height: 1px;
#   padding: 0;
#   margin: -1px;
#   overflow: hidden;
#   clip: rect(0, 0, 0, 0);
#   white-space: nowrap;
#   border-width: 0;
# }
#
# .svg-inline--fa .fa-primary {
#   fill: var(--fa-primary-color, currentColor);
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa .fa-secondary {
#   fill: var(--fa-secondary-color, currentColor);
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-primary {
#   opacity: var(--fa-secondary-opacity, 0.4);
# }
#
# .svg-inline--fa.fa-swap-opacity .fa-secondary {
#   opacity: var(--fa-primary-opacity, 1);
# }
#
# .svg-inline--fa mask .fa-primary,
# .svg-inline--fa mask .fa-secondary {
#   fill: black;
# }
#
# .fad.fa-inverse,
# .fa-duotone.fa-inverse {
#   color: var(--fa-inverse, #fff);
# }</style><link href="https://cf.geekdo-static.com/icons/touch-icon180.png" rel="apple-touch-icon"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="shortcut icon" type="image/ico"/>
# <link href="https://cf.geekdo-static.com/icons/favicon2.ico" rel="icon" type="image/ico"/>
# <link href="/game-opensearch.xml" rel="search" title="BGG Game Search" type="application/opensearchdescription+xml"/>
# <meta content="BGG" name="apple-mobile-web-app-title"/>
# <meta content="#2e2b47" name="theme-color"/>
# <link href="https://api.geekdo.com" rel="preconnect"/>
# <link as="image" href="https://cf.geekdo-images.com/OvFc2vwNA8BEYxwaU2XcFGSGfU0=/825x450/filters:strip_icc()/https%3A%2F%2Fcf.geekdo-static.com%2Fcms%2F2023%2F10%2F13115512%2FBGG-Podcast-EP-28-%25E2%2580%2593-Hero.png" imagesizes="(min-width:1000px) calc(.57 *(100vw - 80px)), (min-width: 768px) 90vw, 100vw" imagesrcset="https://cf.geekdo-images.com/OvFc2vwNA8BEYxwaU2XcFGSGfU0=/825x450/filters:strip_icc()/https%3A%2F%2Fcf.geekdo-static.com%2Fcms%2F2023%2F10%2F13115512%2FBGG-Podcast-EP-28-%25E2%2580%2593-Hero.png 825w, https://cf.geekdo-images.com/Dz9WdNauNRzaiz9xxEi26ya78OI=/0x0/filters:strip_icc()/https%3A%2F%2Fcf.geekdo-static.com%2Fcms%2F2023%2F10%2F13115512%2FBGG-Podcast-EP-28-%25E2%2580%2593-Hero.png 1650w" rel="preload"/>
# <meta content="https://cf.geekdo-static.com/images/opengraph/bgg_opengraph.png" property="og:image"/>
# <meta content="BoardGameGeek" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="The definitive source for board game and card game content. Find millions of ratings, reviews, videos, photos, and more from our community of experts." property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="BoardGameGeek" name="twitter:title"/>
# <meta content="https://cf.geekdo-static.com/images/opengraph/bgg_opengraph.png" name="twitter:image:src"/>
# <meta content="The definitive source for board game and card game content. Find millions of ratings, reviews, videos, photos, and more from our community of experts." name="twitter:description"/>
# <meta content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo" name="keywords"/>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-GMNMCY4DVM&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script>window.AdSlots = window.AdSlots || {
# 	cmd: [],
# 	disableScripts: ['gpt'],
# 	renderOnFirstLoad: false,
# 	divCheck: false
# };</script>
# <title>The Hotness | BoardGameGeek</title><link crossorigin="" href="https://use.typekit.net" rel="preconnect"/>
# <meta charset="utf-8"/>
# <!-- Load the Proxima Nova font -->
# <style type="text/css">@import url("https://p.typekit.net/p.css?s=1&k=ddz3tbb&ht=tk&f=139.140.173.174.175.176&a=962780&app=typekit&e=css");@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/949f99/00000000000000003b9b3068/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n7&v=3") format("woff2"),url("https://use.typekit.net/af/949f99/00000000000000003b9b3068/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n7&v=3") format("woff"),url("https://use.typekit.net/af/949f99/00000000000000003b9b3068/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n7&v=3") format("opentype");font-display:auto;font-style:normal;font-weight:700;font-stretch:normal;}@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/4c4052/00000000000000003b9b3069/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i7&v=3") format("woff2"),url("https://use.typekit.net/af/4c4052/00000000000000003b9b3069/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i7&v=3") format("woff"),url("https://use.typekit.net/af/4c4052/00000000000000003b9b3069/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i7&v=3") format("opentype");font-display:auto;font-style:italic;font-weight:700;font-stretch:normal;}@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/576d53/00000000000000003b9b3066/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n6&v=3") format("woff2"),url("https://use.typekit.net/af/576d53/00000000000000003b9b3066/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n6&v=3") format("woff"),url("https://use.typekit.net/af/576d53/00000000000000003b9b3066/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n6&v=3") format("opentype");font-display:auto;font-style:normal;font-weight:600;font-stretch:normal;}@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/f7d492/00000000000000003b9b3067/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i6&v=3") format("woff2"),url("https://use.typekit.net/af/f7d492/00000000000000003b9b3067/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i6&v=3") format("woff"),url("https://use.typekit.net/af/f7d492/00000000000000003b9b3067/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i6&v=3") format("opentype");font-display:auto;font-style:italic;font-weight:600;font-stretch:normal;}@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/705e94/00000000000000003b9b3062/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n4&v=3") format("woff2"),url("https://use.typekit.net/af/705e94/00000000000000003b9b3062/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n4&v=3") format("woff"),url("https://use.typekit.net/af/705e94/00000000000000003b9b3062/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=n4&v=3") format("opentype");font-display:auto;font-style:normal;font-weight:400;font-stretch:normal;}@font-face {font-family:"proxima-nova";src:url("https://use.typekit.net/af/5c70f2/00000000000000003b9b3063/27/l?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i4&v=3") format("woff2"),url("https://use.typekit.net/af/5c70f2/00000000000000003b9b3063/27/d?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i4&v=3") format("woff"),url("https://use.typekit.net/af/5c70f2/00000000000000003b9b3063/27/a?primer=7cdcb44be4a7db8877ffa5c0007b8dd865b3bbc383831fe2ea177f62257a9191&fvd=i4&v=3") format("opentype");font-display:auto;font-style:italic;font-weight:400;font-stretch:normal;}.tk-proxima-nova{font-family:"proxima-nova",sans-serif;}</style>
# <style type="text/css">
#       body {
#         margin: 0;
#         background-color: #ecedee;
#       }
#
#       main.skeleton-main {
#         display: block;
#         text-align: center;
#         padding: 20px;
#       }
#
#       header.skeleton-header {
#         height: 52px;
#         background-color: #3f3a60;
#       }
#
#       header.skeleton-header nav {
#         max-width: 1550px;
#         padding: 0 15px;
#         margin: 0 auto 1.5rem auto;
#         line-height: normal;
#         position: relative;
#         top: 50%;
#         transform: translateY(-50%);
#         box-sizing: border-box;
#       }
#
#       @media (min-width: 850px) {
#         header.skeleton-header nav {
#           padding-left: 40px;
#         }
#       }
#
#       .skeleton-header-logo,
#       .skeleton-header-item {
#         height: 20px;
#         border-radius: 2px;
#         display: inline-block;
#         vertical-align: middle;
#         margin-right: 15px;
#         background-color: rgba(255, 255, 255, 0.3);
#       }
#
#       .skeleton-header-logo {
#         width: 80px;
#         height: 30px;
#       }
#
#       .skeleton-header-item {
#         width: 60px;
#       }
#
#       @media (max-width: 300px) {
#         .skeleton-header-item:nth-child(n + 3) {
#           display: none;
#         }
#       }
#
#       @media (max-width: 400px) {
#         .skeleton-header-item:nth-child(n + 4) {
#           display: none;
#         }
#       }
#
#       @media (max-width: 500px) {
#         .skeleton-header-item:nth-child(n + 5) {
#           display: none;
#         }
#       }
#
#       @media (max-width: 600px) {
#         .skeleton-header-item:nth-child(n + 6) {
#           display: none;
#         }
#       }
#
#       @media (max-width: 700px) {
#         .skeleton-header-item:nth-child(n + 7) {
#           display: none;
#         }
#       }
#
#       @media (min-width: 850px) {
#         .skeleton-header-logo + .skeleton-header-item {
#           margin-left: 30px;
#         }
#       }
#
#       .loader {
#         position: absolute;
#         top: 25%;
#         width: 100%;
#         left: 0;
#         text-align: center;
#       }
#
#       .line {
#         animation: expand 1s ease-in-out infinite;
#         border-radius: 10px;
#         display: inline-block;
#         transform-origin: center center;
#         margin: 0 3px;
#         width: 3px;
#         height: 15px;
#         border-radius: 10px;
#         background: #c0c5c8;
#       }
#
#       .line:nth-child(2) {
#         animation-delay: 130ms;
#       }
#
#       .line:nth-child(3) {
#         animation-delay: 310ms;
#       }
#
#       .line:nth-child(4) {
#         animation-delay: 490ms;
#       }
#
#       @keyframes expand {
#         0% {
#           transform: scale(1);
#         }
#         25% {
#           transform: scale(2);
#         }
#       }
#     </style>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cf.geekdo-static.com/frontend/styles.953a98fa14f19408.css" rel="stylesheet"/> <link href="https://cf.geekdo-static.com/static/geekng_master2_6526f5c897f81.css" rel="stylesheet" type="text/css"/>
# <meta content="" http-equiv="origin-trial"/><meta content="" http-equiv="origin-trial"/><script async="" src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202310090101/pubads_impl.js?cb=31078750"></script><style type="text/css"></style><style>.main-ad[_ngcontent-ng-c2521749531]{width:1px}</style><script async="" src="/js/prebid_ads_helper.js" type="text/javascript"></script><style>@supports ((position: -webkit-sticky) or (position: sticky)) or (position: -webkit-sticky){[_nghost-ng-c680574602]{z-index:1020;position:-webkit-sticky;position:-webkit-sticky;position:sticky;top:0;display:block}}@media (min-width: 768px){[_nghost-ng-c680574602]{margin-bottom:.9375rem}}@media (min-width: 1000px){[_nghost-ng-c680574602]{margin-bottom:1.25rem}}.c-inner[_ngcontent-ng-c680574602]{height:52px}  .c-nav-primary{margin:0;display:inline-block;list-style-type:none;white-space:nowrap;padding:0}  .c-nav-primary>ul{margin:0;padding:0}  .c-nav-primary li.dropdown-primary,   .c-nav-primary gg-my-geek .dropdown-primary{margin-right:0;display:inline-block;background-color:transparent;color:var(--white)}  .c-nav-primary li.dropdown-primary .dropdown-menu,   .c-nav-primary gg-my-geek .dropdown-primary .dropdown-menu{max-width:300px}  .c-nav-primary li.dropdown-primary>.btn,   .c-nav-primary gg-my-geek .dropdown-primary>.btn{cursor:pointer;background-color:transparent;padding:7px;vertical-align:baseline;font-weight:700;line-height:1;color:var(--white)}@media (max-width: 1100px){  .c-nav-primary li.dropdown-primary>.btn,   .c-nav-primary gg-my-geek .dropdown-primary>.btn{padding:5px!important;font-size:.8125rem!important}}  .c-nav-primary li.dropdown-primary>.btn:hover,   .c-nav-primary li.dropdown-primary>.btn:focus,   .c-nav-primary li.dropdown-primary>.btn:active,   .c-nav-primary gg-my-geek .dropdown-primary>.btn:hover,   .c-nav-primary gg-my-geek .dropdown-primary>.btn:focus,   .c-nav-primary gg-my-geek .dropdown-primary>.btn:active{background-color:var(--purple-dark);color:var(--white);-webkit-text-decoration-line:none;text-decoration-line:none}  .c-nav-primary li.dropdown-primary .dropdown-toggle:after,   .c-nav-primary gg-my-geek .dropdown-primary .dropdown-toggle:after{margin-left:0;border-width:4px}</style><style>.geeksidebar[_nghost-ng-c1886665604], .geeksidebar   [_nghost-ng-c1886665604]{background-color:#fff}.geeksidebar[_nghost-ng-c1886665604]   button.btn[_ngcontent-ng-c1886665604], .geeksidebar   [_nghost-ng-c1886665604]   button.btn[_ngcontent-ng-c1886665604]{display:block;width:100%;text-align:left;color:#000;background:transparent;padding-left:0;padding-right:0}.geeksidebar[_nghost-ng-c1886665604]   .dropdown-header[_ngcontent-ng-c1886665604], .geeksidebar   [_nghost-ng-c1886665604]   .dropdown-header[_ngcontent-ng-c1886665604]{padding-left:0}.geeksidebar[_nghost-ng-c1886665604]   ul[_ngcontent-ng-c1886665604], .geeksidebar   [_nghost-ng-c1886665604]   ul[_ngcontent-ng-c1886665604]{margin:0;padding:0}.geeksidebar[_nghost-ng-c1886665604]   li.dropdown-primary[_ngcontent-ng-c1886665604], .geeksidebar   [_nghost-ng-c1886665604]   li.dropdown-primary[_ngcontent-ng-c1886665604]{display:block;line-height:1.8;padding:0;margin-right:0;position:relative;border-bottom:1px solid #ecedee}.geeksidebar[_nghost-ng-c1886665604]   li.dropdown-primary[_ngcontent-ng-c1886665604]:last-child, .geeksidebar   [_nghost-ng-c1886665604]   li.dropdown-primary[_ngcontent-ng-c1886665604]:last-child{border-bottom:none}.geeksidebar ...
# </style><style>.card-scroll__list{--grid-row-gap: .9375rem;--border-color: #d1d4d7}.game-list{--img-margin: .9375rem;padding-bottom:var(--grid-row-gap)}.game-list__img{margin-right:var(--img-margin);transition:filter .15s ease-in-out;border-radius:4px}.game-list:hover .game-list__img,.game-list:focus-within .game-list__img{filter:var(--img-hover)}.game-list:hover .game-list__description,.game-list:focus-within .game-list__description{text-decoration:underline;-webkit-text-decoration-color:#878f96;text-decoration-color:#878f96}.tw-text-white .game-list__description{-webkit-text-decoration-color:rgba(255,255,255,.5)!important;text-decoration-color:#ffffff80!important}.card-scroll__list--2-rows .card-scroll__item:nth-child(odd) .game-list{border-bottom:1px solid var(--border-color)}.card-scroll__list--3-rows .card-scroll__item:nth-child(3n+1) .game-list,.card-scroll__list--3-rows .card-scroll__item:nth-child(3n+2) .game-list{border-bottom:1px solid var(--border-color)}.tw-text-white .card-scroll__list{--border-color: rgba(255, 255, 255, .25)}
# </style><style>.spotlight{--header-overlay-tint: rgba(0, 0, 0, .75);--min-tab-height: 13.125rem}@media (min-width: 768px){.spotlight{--min-tab-height: 18.75rem}}@media (min-width: 1100px){.spotlight{--min-tab-height: 22.1875rem}}.youtube.spotlight,.guild.spotlight{--header-overlay-tint: rgba(0, 0, 0, .5);--min-tab-height: 0}.spotlight__header{z-index:1}.spotlight__header:after,.spotlight__banner-img{content:"";position:absolute;top:0;left:0;width:100%;height:100%;z-index:-1}.spotlight__header:after{background-image:linear-gradient(180deg,var(--header-overlay-tint) 35%,#000 98%)}.spotlight__banner-img{object-fit:cover;object-position:center center}@media (max-width: 767px){.spotlight__banner-img{filter:blur(20px) saturate(1.5)}}.spotlight__profile-img{max-width:200px;transition:filter .15s ease-in-out}.spotlight__info-container:hover .spotlight__profile-img,.spotlight__info-container:focus-within .spotlight__profile-img,.photo-card-scroll__link:hover .photo-card-scroll__img,.photo-card-scroll__link:focus .photo-card-scroll__img{filter:var(--img-hover)}.spotlight__meta,.spotlight__game-description{opacity:.75}@media (min-width: 1100px){.spotlight__meta{font-size:.9375rem}}@media (min-width: 768px){.spotlight__title{font-size:1.5rem}}@media (min-width: 1100px){.spotlight__body{font-size:1rem}}@media (max-width: 767px){.spotlight__game-title{font-size:.875rem}}@media (min-width: 576px){.spotlight__game-description{font-size:.875rem}}@media (min-width: 1100px){.spotlight__game-description{font-size:1rem}}.spotlight__nav-tab-container{-webkit-overflow-scrolling:touch}.spotlight .nav-tabs{border-bottom-color:#ffffff40}.spotlight .nav-tabs .nav-item{flex-grow:0;flex-shrink:0}.spotlight .nav-tabs .nav-link{margin-right:.3125rem;padding:.5rem .625rem;font-size:.75rem;font-weight:700;color:#ffffffbf;text-transform:uppercase;transition:.2s color ease-in-out}@media (min-width: 1000px){.spotlight .nav-tabs .nav-link{font-size:.875rem}}.spotlight .nav-tabs .nav-link.active,.spotlight .nav-tabs .nav-link:hover,.spotlight .nav-tabs .nav-link:focus{color:#fff!important}.spotlight__empty-state,.tab-pane{min-height:var(--min-tab-height)}.photo-card-scroll{--grid-column-gap: 8px;--grid-row-gap: 8px;--grid-row-height: 75px;--grid-rows: repeat(2, var(--grid-row-height));grid-auto-columns:calc((100% - 4 * var(--grid-column-gap) - var(--module-padding)) / 5);grid-template-rows:var(--grid-rows)}@media (min-width: 768px){.photo-card-scroll{--grid-column-gap: 12px;--grid-row-gap: 12px;--grid-row-height: 115px;grid-auto-columns:calc((100% - 7 * var(--grid-column-gap) - var(--module-padding)) / 8)}}@media (min-width: 1100px){.photo-card-scroll{--grid-row-height: 130px;grid-auto-columns:calc((100% - 9 * var(--grid-column-gap) - var(--module-padding)) / 10)}}.photo-card-scroll :nth-child(17n+1){grid-column:span 2;grid-row:span 2}.photo-card-scroll :nth-child(6n){grid-column:span 2}.photo-card-scroll__img{object-fit:cover;transition:filter .15s ease-in-out}.video-card-scroll{grid-template-columns:repeat(var(--column-count),var(--item-min-width)) -webkit-max-content;grid-template-columns:repeat(var(--column-count),var(--item-min-width)) max-content}@media (min-width: 768px){.video-card-scroll{grid-template-columns:repeat(var(--column-count),calc((100% - 2 * var(--grid-column-gap) - var(--module-padding)) / 3)) -webkit-max-content;grid-template-columns:repeat(var(--column-count),calc((100% - 2 * var(--grid-column-gap) - var(--module-padding)) / 3)) max-content}}@media (min-width: 1000px){.video-card-scroll{grid-template-columns:repeat(var(--column-count),calc((100% - 3 * var(--grid-column-gap) - var(--module-padding)) / 4)) -webkit-max-content;grid-template-columns:repeat(var(--column-count),calc((100% - 3 * var(--grid-column-gap) - var(--module-padding)) / 4)) max-content}}.forum-card-scroll{--grid-rows: 4;--grid-row-gap: 0;grid-template-columns:repeat(var(--column-count),calc(100% - var(--grid-column-gap) * 2)) -webkit-max-content;grid-template-columns:repeat ...
# </style><style>.forum-list__item{--row-gap: .75rem;--border-color: #d1d4d7;--img-size: 3.75rem}.forum-list__item:not(:last-child){padding-bottom:var(--row-gap);margin-bottom:var(--row-gap);border-bottom:1px solid var(--border-color)}.forum-list__img-container{margin-right:var(--row-gap);width:var(--img-size);height:var(--img-size)}.forum-list__body{min-width:0}.forum-list__img{width:auto;height:var(--img-size);object-fit:contain;border-radius:6px;transition:filter .15s ease-in-out}.forum-list__item:hover .forum-list__img,.forum-list__item:focus-within .forum-list__img{filter:var(--img-hover)}.forum-list__title{line-height:1.2;margin-bottom:.1875rem}@media (max-width: 1279px){.forum-list__title{font-size:.875rem}}.tw-text-white .forum-list__item{--border-color: rgba(255, 255, 255, .25)}
# </style><style>.advertisement-leaderboard-lg[_ngcontent-ng-c559065832]{min-height:90px}</style><style>[_nghost-ng-c743284836]{display:block;position:-webkit-sticky;position:-webkit-sticky;position:sticky;top:52px;z-index:1018}@media (min-width: 1000px){[_nghost-ng-c743284836]{font-size:1.125rem}}.home-tab-container[_ngcontent-ng-c743284836]{overflow-y:hidden;overflow-x:auto;-webkit-overflow-scrolling:touch}.home-tab[_ngcontent-ng-c743284836]{padding:0 var(--module-padding)}@media (min-width: 768px){.home-tab[_ngcontent-ng-c743284836]{margin:0 var(--module-padding);padding:0}}@media (max-width: 767px){.home-tab__item[_ngcontent-ng-c743284836]{flex:1 1 auto}}</style><style>[_nghost-ng-c1362059419]{display:block;--list-img-size: 4.6875rem}@media (min-width: 768px){[_nghost-ng-c1362059419]{padding:var(--module-padding)}}@media (min-width: 1000px){.feat-grid[_ngcontent-ng-c1362059419]{display:grid;grid-template-columns:1fr 43%;grid-template-areas:"hero list";grid-gap:0 1.5625rem}}@media (min-width: 1280px){.feat-grid[_ngcontent-ng-c1362059419]{grid-gap:0 2.1875rem}}.feat-hero[_ngcontent-ng-c1362059419]{grid-area:hero}  .feat-hero__img{width:100%}@media (min-width: 768px){  .feat-hero__img{border-radius:6px}}.feat-hero__caption[_ngcontent-ng-c1362059419]{margin-top:-1.25rem;padding:1.25rem 2.1875rem 1.25rem .9375rem;max-width:95%;-webkit-clip-path:polygon(0 0,0 100%,100% 100%,100% 50%,calc(100% - 12px) calc(0% + 8px));clip-path:polygon(0 0,0 100%,100% 100%,100% 50%,calc(100% - 12px) calc(0% + 8px));z-index:2}@media (min-width: 768px){.feat-hero__caption[_ngcontent-ng-c1362059419]{margin-top:-1.875rem;padding:1.875rem 2.8125rem 1.875rem .9375rem}}@media (min-width: 1000px){.feat-hero__caption[_ngcontent-ng-c1362059419]{margin-top:-2.1875rem;padding-bottom:0;padding-left:0}}.feat-hero__title[_ngcontent-ng-c1362059419]{margin-bottom:.5rem;font-size:1.125rem;line-height:1.2}@media (min-width: 768px){.feat-hero__title[_ngcontent-ng-c1362059419]{font-size:1.25rem}}.feat-list[_ngcontent-ng-c1362059419]{grid-area:list;align-self:center;padding-left:0;list-style:none}@media (max-width: 999px){.feat-list[_ngcontent-ng-c1362059419]{padding:1.25rem .9375rem;border-top:1px solid #d1d4d7}}@media (min-width: 768px) and (max-width: 999px){.feat-list[_ngcontent-ng-c1362059419]{display:grid;padding:1.25rem 0;grid-gap:0 .9375rem;grid-template-columns:1fr 1fr;grid-auto-flow:row}}@media (min-width: 1430px){.feat-list[_ngcontent-ng-c1362059419]{padding-bottom:2.8125rem}}.feat-list__item[_ngcontent-ng-c1362059419]{padding-bottom:.9375rem;margin-bottom:.9375rem;border-bottom:1px solid #d1d4d7}.feat-list__item[_ngcontent-ng-c1362059419]:after{content:"";position:absolute;right:0;bottom:0;width:0;height:0;border-bottom:7px solid #d1d4d7;border-left:7px solid transparent}@media (min-width: 768px) and (max-width: 999px){.feat-list__item[_ngcontent-ng-c1362059419]:nth-last-child(-n+2){margin-bottom:0;padding-bottom:0;border-bottom:none}.feat-list__item[_ngcontent-ng-c1362059419]:nth-last-child(-n+2):after{display:none}}.feat-list__item[_ngcontent-ng-c1362059419]:last-of-type{margin-bottom:0;padding-bottom:0;border-bottom:none}.feat-list__item[_ngcontent-ng-c1362059419]:last-of-type:after{display:none}  .feat-list__img{width:var(--list-img-size);height:var(--list-img-size);margin-right:.9375rem;object-fit:cover;border-radius:6px}  .feat-hero__img,   .feat-list__img{transition:filter .15s ease-in-out}.feat-hero[_ngcontent-ng-c1362059419]:hover     .feat-hero__img, .feat-hero[_ngcontent-ng-c1362059419]:hover     .feat-list__img, .feat-hero[_ngcontent-ng-c1362059419]:focus-within     .feat-hero__img, .feat-hero[_ngcontent-ng-c1362059419]:focus-within     .feat-list__img, .feat-list__item[_ngcontent-ng-c1362059419]:hover     .feat-hero__img, .feat-list__item[_ngcontent-ng-c1362059419]:hover     .feat-list__img, .feat-list__item[_ngcontent-ng-c1362059419]:focus-within     .feat-hero__img, .feat-list__item[_ngcontent-ng-c1362059419]:focus-within     .feat-list__img{fi ...
# <body class="domain-boardgame">
# <gg-app _nghost-ng-c2521749531="" ng-version="16.2.1"><div _ngcontent-ng-c2521749531="" class="tw-flex tw-min-h-screen tw-flex-col"><div _ngcontent-ng-c2521749531="" id="required"><div _ngcontent-ng-c2521749531="" class="main-ad leaderboard"></div></div><gg-header _ngcontent-ng-c2521749531="" _nghost-ng-c680574602=""><header _ngcontent-ng-c680574602="" class="header tw-relative tw-bg-purple print:tw-hidden"><nav _ngcontent-ng-c680574602="" class="container-fluid tw-px-[7px] tw-py-0"><div _ngcontent-ng-c680574602="" class="c-inner tw-flex"><button _ngcontent-ng-c680574602="" class="btn btn-lg btn-light tw-sr-only tw-top-2 tw-z-10 focus:tw-not-sr-only focus:tw-absolute focus:tw-ml-2 focus:tw-px-2 focus:tw-py-1" type="button"> Skip Navigation </button><a _ngcontent-ng-c680574602="" class="btn btn-lg btn-light tw-sr-only tw-top-2 tw-z-10 focus:tw-not-sr-only focus:tw-absolute focus:tw-ml-2 focus:tw-px-2 focus:tw-py-1" href="/contact" onclick="this.blur()" routerlink="/contact">Accessibility Feedback</a><button _ngcontent-ng-c680574602="" class="btn btn-empty header-icon tw-mr-2 tw-hidden tw-self-center tw-rounded tw-p-1.5 tw-leading-none tw-outline-none hover:tw-bg-purple-dark hover:tw-text-white focus:tw-bg-purple-dark focus:tw-text-white xl:tw-block" type="button"><svg _ngcontent-ng-c680574602="" aria-hidden="true" class="menu-bars" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path _ngcontent-ng-c680574602="" d="M14 12v1H0v-1h14zm0-6v1H0V6h14zm0-6v1H0V0h14z" fill="#FFF" fill-rule="nonzero"></path></svg><span _ngcontent-ng-c680574602="" class="tw-sr-only tw-text-white">Toggle Sidebar</span></button><button _ngcontent-ng-c680574602="" class="btn btn-empty header-icon tw-mr-2 tw-self-center tw-rounded tw-p-1.5 tw-leading-none tw-outline-none hover:tw-bg-purple-dark hover:tw-text-white focus:tw-bg-purple-dark focus:tw-text-white xl:tw-hidden" type="button"><svg _ngcontent-ng-c680574602="" aria-hidden="true" class="menu-bars" height="13" width="14" xmlns="http://www.w3.org/2000/svg"><path _ngcontent-ng-c680574602="" d="M14 12v1H0v-1h14zm0-6v1H0V6h14zm0-6v1H0V0h14z" fill="#FFF" fill-rule="nonzero"></path></svg><span _ngcontent-ng-c680574602="" class="tw-sr-only tw-text-white">Show Menu</span></button><gg-menu-logo _ngcontent-ng-c680574602="" class="tw-flex-shrink-0 tw-basis-auto tw-self-center"><div class="menu-logo-inner"><a class="tw-text-white" href="/"><img alt="boardgame geek logo" aria-hidden="true" class="menu-logo-symbol tw-max-w-[64px] md:tw-max-w-none" height="38" src="https://cf.geekdo-static.com/images/logos/navbar-logo-bgg-b2.svg" width="80"/><h1 class="tw-sr-only">boardgame geek</h1><!-- --></a><!-- --><!-- --><!-- --><div class="tw-inline-block tw-align-middle dropdown" ngbdropdown=""><button aria-expanded="false" class="dropdown-toggle btn btn-empty tw-ml-1 tw-rounded tw-px-1.5 tw-py-1 tw-text-center tw-leading-none tw-text-white tw-transition-colors after:tw-border-4 after:tw-opacity-60 hover:tw-bg-purple-dark focus:tw-bg-purple-dark active:tw-bg-purple-dark md:tw-block lg:tw-mx-1.5 lg:tw-my-0" ngbdropdowntoggle="" type="button"><span class="tw-sr-only">More Geek Sites</span></button><div class="dropdown-menu" ngbdropdownmenu=""><span class="dropdown-header tw-pt-0">More Geek Sites</span><a class="dropdown-item" href="https://rpggeek.com" role="menuitem">RPGGeek</a><a class="dropdown-item" href="https://videogamegeek.com" role="menuitem">VideoGameGeek</a><a class="dropdown-item" href="/bggcon" role="menuitem">Geek Events</a><!-- --></div></div></div><!-- --></gg-menu-logo><div _ngcontent-ng-c680574602="" class="c-nav tw-relative tw-flex-auto tw-self-center"><div _ngcontent-ng-c680574602="" class="c-nav-primary-wrapper tw-flex tw-justify-between tw-whitespace-nowrap"><div _ngcontent-ng-c680574602="" _nghost-ng-c1886665604="" class="c-nav-primary tw-hidden tw-flex-1 lg:tw-block" ggmenunav=""><ul _ngcontent-ng-c1886665604=""><li _ngcontent-ng-c1886665604="" class="dropdown-primary dropdown" ngbdropdown="" p ...
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	gtag('consent', 'default', {
# 		'ad_storage': 'denied',
# 		'analytics_storage': 'denied',
# 		'personalization_storage': 'denied',
# 		'wait_for_update': 3000
# 	});
# 	gtag('config', 'UA-104725-1', {
# 		'cookie_domain': 'boardgamegeek.com',
# 		'send_page_view': false
# 	});
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
# 	var googletag = googletag || {};
# 	var grecaptcha = grecaptcha || {};
# 	var google = google || {};
# 	googletag.cmd = googletag.cmd || [];
#
#
#
# 	window.GEEK = {
# 		geeksite: 'boardgame',
# 		recaptcha_public: '6Ldyr6EaAAAAAE0F2hYgtHHqbF6nKPTENAwo6SyU',
# 		stripe_public: 'pk_live_Bg0TwgF6emmzXngnwsbgu2AL',
# 		analytics_id: 'UA-104725-1',
# 		places_key: 'AIzaSyDp84ECUWfUUBV1Q90aMKE7Fb2P7mNRr9g'
# 	};
# 		</script>
# <script src="https://cf.geekdo-static.com/static/geekng_master2_6526f5c897f81.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="https://cf.geekdo-static.com/frontend/runtime.1f4a629000243794.js" type="module"></script><script crossorigin="anonymous" src="https://cf.geekdo-static.com/frontend/polyfills.cdedf881fce6fcca.js" type="module"></script><script crossorigin="anonymous" src="https://cf.geekdo-static.com/frontend/main.fd877e3c867e0b4c.js" type="module"></script><iframe src="https://6022c6f39aefa59c05118e569edbfa1e.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="visibility: hidden; display: none;"></iframe>
# <div aria-atomic="true" aria-live="polite" class="visually-hidden" id="ngb-live">No results available</div><div class="c--anim" id="cc--main" style="position: fixed; z-index: 1000000;"><!--[if lt IE 9 ]><div id="cc_div" class="cc_div ie"></div><![endif]--><!--[if (gt IE 8)|!(IE)]><!--><div class="cc_div" id="cc_div"><div aria-hidden="true" aria-labelledby="s-ttl" aria-modal="true" class="slide" id="s-cnt" role="dialog" style="visibility: hidden;"><div id="c-vln"><div id="cs"><div id="c-s-in"><div class="bns-t" id="s-inr"><div id="s-hdr"><div id="s-ttl" role="heading">Your Cookie Privacy Options</div><div id="s-c-bnc"><button aria-label="Close" class="c-bn" id="s-c-bn" type="button"></button></div></div><div id="s-bl"><div class="c-bl"><div class="title"><div aria-level="3" class="b-tl" role="heading">Cookie Usage</div></div><div class="desc"><div class="p">Below are the categories of cookies we use to ensure the basic functionality of the site and to enhance your experience.</div></div></div><div class="c-bl b-ex"><div class="title b-bn"><button aria-controls="c-ac-1" aria-expanded="false" class="b-tl exp" type="button">Essential</button><label class="b-tg"><input class="c-tgl" disabled="" type="checkbox" value="necessary"/><span aria-hidden="true" class="c-tg c-ro"><span class="on-i"></span><span class="off-i"></span></span><span class="t-lb">Essential</span></label></div><div aria-hidden="true" class="desc b-acc" id="c-ac-1"><div class="p">We rely on these cookies to remember your preferences, login info, and prevent abuse and fraud.</div><table><thead><tr><th scope="col">Name</th><th scope="col">Domain</th><th scope="col">Expiration</th><th scope="col">Description</th><th scope="col">Policy Info</th></tr></thead><tbody><tr><td data-column="Name">cc_cookie</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">1 Year</td><td data-column="Description">Saves these Settings</td><td data-column="Policy Info"><a href="/privacy#toc13" target="_blank">Policy</a></td></tr><tr><td data-column="Name">bggusername</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">1 Month</td><td data-column="Description">User Login</td><td data-column="Policy Info"><a href="/privacy#toc13" target="_blank">Policy</a></td></tr><tr><td data-column="Name">bggpassword</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">1 Month</td><td data-column="Description">User Login</td><td data-column="Policy Info"><a href="/privacy#toc13" target="_blank">Policy</a></td></tr><tr><td data-column="Name">SessionID</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">3 Hours</td><td data-column="Description">User Login</td><td data-column="Policy Info"><a href="/privacy#toc13" target="_blank">Policy</a></td></tr><tr><td data-column="Name">_GRECAPTCHA</td><td data-column="Domain">www.recaptcha.net</td><td data-column="Expiration">6 Months</td><td data-column="Description">Abuse Prevention</td><td data-column="Policy Info"><a href="https://policies.google.com/privacy?hl=en#infocollect" target="_blank">Policy</a></td></tr><tr><td data-column="Name">__stripe_sid</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">30 Min</td><td data-column="Description">Fraud Prevention by Payment Processor</td><td data-column="Policy Info"><a href="https://stripe.com/privacy" target="_blank">Policy</a></td></tr><tr><td data-column="Name">__stripe_mid</td><td data-column="Domain">.boardgamegeek.com</td><td data-column="Expiration">1 Year</td><td data-column="Description">Fraud Prevention by Payment Processor</td><td data-column="Policy Info"><a href="https://stripe.com/privacy" target="_blank">Policy</a></td></tr><tr><td data-column="Name">__stripe_sid, plus others</td><td data-column="Domain">.stripe.com</td><td data-column="Expiration">30 Min</td><td data-column="Description">Fraud Prevention by Payment Processor</td><td data-column="Policy Info"><a h ...

# %%
titulos = soup.select('div.global-body-content-container.container-fluid h3 a')
lista = []
for titulo in titulos:
    lista.append(titulo.get_text())
lista
# Out:
# [' Space Marine: The Board Game ',
#  ' The White Castle ',
#  ' Ancient Knowledge ',
#  ' Nucleum ',
#  ' Evacuation ',
#  ' Voidfall ',
#  ' Kutná Hora: The City of Silver ',
#  ' Dune: Imperium – Uprising ',
#  ' Heat: Pedal to the Metal ',
#  ' Moon ',
#  ' Septima ',
#  ' Ark Nova ',
#  ' Evenfall ',
#  ' Sky Team ',
#  ' Forest Shuffle ',
#  ' Dune: Imperium ',
#  ' Brass: Birmingham ',
#  ' Expeditions ',
#  ' Spirit Island ',
#  ' The Witcher: Old World ',
#  ' Oathsworn: Into the Deepwood ',
#  ' The Witcher: Path Of Destiny ',
#  ' Rats of Wistar ',
#  ' Terraforming Mars ',
#  ' Apiary ',
#  ' Revive ',
#  ' Age of Innovation ',
#  ' Ark Nova: Marine Worlds ',
#  ' Sea Salt & Paper ',
#  ' Hegemony: Lead Your Class to Victory ',
#  ' Unmatched Adventures: Tales to Amaze ',
#  ' Planta Nubo ',
#  ' Cascadia ',
#  ' Lost Ruins of Arnak ',
#  ' Wingspan ',
#  ' Everdell ',
#  ' Faraway ',
#  ' Earth ',
#  ' The Castles of Burgundy: Special Edition ',
#  ' Root ',
#  ' Arkham Horror: The Card Game ',
#  ' Obsession ',
#  ' Art Society ',
#  ' Scythe ',
#  ' Final Girl ',
#  ' Theme Park Mania ',
#  ' Path of Civilization ',
#  ' Marvel Champions: The Card Game ',
#  " Darwin's Journey ",
#  ' Cascadero ']

# %%
driver.back()

# %%
browse = driver.find_element(By.XPATH, '/html/body/gg-app/div/gg-header/header/nav/div/div[1]/div/div[1]/ul/li[1]/button')
browse.click()

# %%
all_games = driver.find_element(By.XPATH, '/html/body/gg-app/div/gg-header/header/nav/div/div[1]/div/div[1]/ul/li[1]/div/div/div/div[1]/span[1]/a')
all_games.click()

# %%
driver.close()

# %% [markdown]
# # Ahora algo más visual

# %%
driver = webdriver.Chrome()

url = 'https://www.filmaffinity.com/es/main.html'

driver.get(url)

# %% [markdown]
# La página de Filmaffinity se ha abierto pero nos vuelven a molestar las cookies

# %%
element_by_xpath = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div/div[2]/div/button[2]')

# %% [markdown]
# Una vez tenemos los elementos podemos hacer varias cosas con ellos
#
# vamos a ver...

# %%
dir(element_by_xpath)
# Out:
# ['__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_execute',
#  '_id',
#  '_parent',
#  '_upload',
#  'accessible_name',
#  'aria_role',
#  'clear',
#  'click',
#  'find_element',
#  'find_elements',
#  'get_attribute',
#  'get_dom_attribute',
#  'get_property',
#  'id',
#  'is_displayed',
#  'is_enabled',
#  'is_selected',
#  'location',
#  'location_once_scrolled_into_view',
#  'parent',
#  'rect',
#  'screenshot',
#  'screenshot_as_base64',
#  'screenshot_as_png',
#  'send_keys',
#  'shadow_root',
#  'size',
#  'submit',
#  'tag_name',
#  'text',
#  'value_of_css_property']

# %% [markdown]
# Podemos evaluar que tipo de elemento es (tag)

# %%
element_by_xpath.tag_name
# Out:
# 'button'

# %% [markdown]
# Podemos sacar el valor que tiene (el texto)

# %%
element_by_xpath.text
# Out:
# 'ACEPTO'

# %%
element_by_xpath.screenshot('mi_imagen.png')
# Out:
# True

# %% [markdown]
# Bueno vamos a seguir

# %%
element_by_xpath.click()

# %% [markdown]
# Vamos a buscar una pelicula por su nombre

# %%
buscador = driver.find_element(By.XPATH, '/html/body/header/div[1]/div/div[2]/div/form/div/input')

# %%
buscador.send_keys('titanicas')

# %% [markdown]
# Está mal escrito limpiamos

# %%
buscador.clear()

# %%
buscador.send_keys('titanic')

# %%
buscador.send_keys(Keys.ENTER)

# %%
driver.back()

# %%
for i in range(20):

    driver.execute_script("window.scrollBy(0, 250)")

    time.sleep(1)

# %% [markdown]
# Control de ventanas

# %%
driver.execute_script('window.open("");')

# %%
driver.switch_to.window(driver.window_handles[0])

# %%
driver.close()

# %%
driver.switch_to.window(driver.window_handles[-1])

# %%
driver.close()
